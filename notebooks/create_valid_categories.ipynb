# %%
import pandas as pd

# %%
df = pd.read_parquet('../data/preprocessed/PreprocessedDataset.parquet')

# %%
cat_columns = ['use_chip', 'merchant_city', 'errors', 'gender', 'card_brand', 'card_type', 'has_chip', 'merchant_category']

# %%
valid_categories = {col: df[col].dropna().unique().tolist() for col in cat_columns}

# %%
import json

# %%
with open('../app/valid_categories.json', 'w') as f:
    json.dump(valid_categories, f)
